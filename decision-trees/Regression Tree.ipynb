# %%
import pandas as pd
from pandas_datareader import data
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import GridSearchCV

# %%
housing = fetch_california_housing()
df = pd.DataFrame(housing.data, columns=housing.feature_names)
df['target'] = housing.target
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  ...  AveOccup  Latitude  Longitude  target
# 0  8.3252      41.0  6.984127   1.023810  ...  2.555556     37.88    -122.23   4.526
# 1  8.3014      21.0  6.238137   0.971880  ...  2.109842     37.86    -122.22   3.585
# 2  7.2574      52.0  8.288136   1.073446  ...  2.802260     37.85    -122.24   3.521
# 3  5.6431      52.0  5.817352   1.073059  ...  2.547945     37.85    -122.25   3.413
# 4  3.8462      52.0  6.281853   1.081081  ...  2.181467     37.85    -122.25   3.422
#
# [5 rows x 9 columns]

# %%
df.shape
# Out:
# (20640, 9)

# %%
x = df.iloc[:,0:8]
y = df.iloc[:,8]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
rt = DecisionTreeRegressor(criterion = 'poisson', max_depth=4)

# %%
rt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='poisson', max_depth=4)

# %%
y_pred = rt.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5663450235586619

# %% [markdown]
# HyperParameter Tuning

# %%
param_grid = {
    'max_depth': [2, 4, 8, 10],
    'criterion': ['squared_error'],
    'max_features': [1.0],
    'min_samples_split': [2, 4],
    'min_samples_leaf': [1, 2]
}

# %%
reg = GridSearchCV(DecisionTreeRegressor(), param_grid = param_grid)

# %%
reg.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error'],
#                          'max_depth': [2, 4, 8, 10], 'max_features': [1.0],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 4]})

# %%
reg.best_score_
# Out:
# np.float64(0.6997234677232926)

# %%
reg.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 8,
#  'max_features': 1.0,
#  'min_samples_leaf': 2,
#  'min_samples_split': 4}

# %% [markdown]
# Feature Importance

# %%
for importance, name in sorted(zip(rt.feature_importances_, x_train.columns), reverse=True):
  print(name, importance)
# Out:
# MedInc 0.7923755080044372
# AveOccup 0.1217982193045224
# AveRooms 0.03721675562776281
# Latitude 0.02939370775105764
# HouseAge 0.019215809312219976
# Population 0.0
# Longitude 0.0
# AveBedrms 0.0
