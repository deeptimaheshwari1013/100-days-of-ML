# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Day 49 Regression Metrics Placement.csv')

df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package in lpa')
# Out:
# Text(0, 0.5, 'Package in lpa')

# %%
X= df.iloc[:,0:1]
y = df.iloc[:,-1]

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('package in lpa')
# Out:
# Text(0, 0.5, 'package in lpa')

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred = lr.predict(x_test)
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 0.2884710931878175

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 0.12129235313495527

# %%
print("RMSE",np.sqrt(mean_absolute_error(y_test,y_pred)))
# Out:
# RMSE 0.5370950504220063

# %%
print("r2_score",r2_score(y_test,y_pred))

r2 = r2_score(y_test,y_pred)
# Out:
# r2_score 0.780730147510384

# %%
# adjusted r2 score

1 - ((1-r2)*(40-1)/(40-1-1))
# Out:
# 0.7749598882343415

# %%
new_df1 = df.copy()
new_df1['random_feature'] = np.random.random(200)

new_df1 = new_df1[['cgpa','random_feature','package']]

new_df1.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.564667     3.26
# 1  5.12        0.694625     1.98
# 2  7.82        0.464788     3.25
# 3  7.42        0.468534     3.67
# 4  6.94        0.297760     3.57

# %%
plt.scatter(new_df1['random_feature'],new_df1['package'])
plt.xlabel("random_feature")
plt.ylabel("package")
# Out:
# Text(0, 0.5, 'package')

# %%
x = new_df1.iloc[:,0:2]
y = new_df1.iloc[:,-1]

x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=2,test_size=0.2)

lr = LinearRegression()
lr.fit(x_train,y_train)

y_pred = lr.predict(x_test)

print("r2_Scrore",r2_score(y_test,y_pred))

r2 = r2_score(y_test,y_pred)
# Out:
# r2_Scrore 0.7812696285563147

# %%
1 - ((1-r2) * (40-1)/(40-1-2))
# Out:
# 0.7694463652350343

# %%
new_df2 = df.copy()

new_df2['iq']= new_df2['package'] + (np.random.randint(-12,12,200)/10)

new_df2 = new_df2[['cgpa','iq','package']]

# %%
plt.scatter(new_df2['iq'],new_df2['package'])
plt.xlabel("iq")
plt.ylabel("package in lpa")
# Out:
# Text(0, 0.5, 'package in lpa')

# %%
X = new_df2.iloc[:,0:2]
y = new_df2.iloc[:,-1]

x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=2)

lr = LinearRegression()
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)

print("r2_score",r2_score(y_test,y_pred))

r2 = r2_score(y_test,y_pred)

1 - ((1-r2) * (40-1)/(40-1-2))
# Out:
# r2_score 0.8273906435358919
# 0.8180604080513455
