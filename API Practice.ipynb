# %%
# !pip install pandas
# !pip install requests

# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ -----------
# anaconda-anon-usage      0.7.2
# anaconda-auth            0.8.6
# anaconda-cli-base        0.5.2
# annotated-types          0.6.0
# archspec                 0.2.3
# boltons                  25.0.0
# brotlicffi               1.0.9.2
# certifi                  2025.8.3
# cffi                     1.17.1
# charset-normalizer       3.3.2
# click                    8.2.1
# colorama                 0.4.6
# conda                    25.7.0
# conda-anaconda-telemetry 0.3.0
# conda-anaconda-tos       0.2.2
# conda-content-trust      0.2.0
# conda-libmamba-solver    25.4.0
# conda-package-handling   2.4.0
# conda_package_streaming  0.12.0
# cryptography             45.0.5
# distro                   1.9.0
# frozendict               2.4.2
# idna                     3.7
# jaraco.classes           3.2.1
# jaraco.context           0.0.0
# jaraco.functools         4.1.0
# jsonpatch                1.33
# ...

# %%
import pandas as pd 
import requests

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJhOTExNjBmMWNmYzU5MzhlZDQyNDRhMzA3ZjliMTZiMCIsIm5iZiI6MTc2ODY0NzcyNC4wOTIsInN1YiI6IjY5NmI2YzJjMTdjZGEwNjRjNjdmOTk1OCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.h8TRO1pG8EOTw-iLwvNJ9TG4UCtie0RcXApCtLDpCnU"
}
response = requests.get(url, headers=headers)
df = pd.DataFrame(response.json()['results'])[['id','title','overview','popularity','release_date','vote_average','vote_count']]

# %%
df1 = pd.DataFrame()

# %%
for i in (1,200):
    url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={}".format(i)
    headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJhOTExNjBmMWNmYzU5MzhlZDQyNDRhMzA3ZjliMTZiMCIsIm5iZiI6MTc2ODY0NzcyNC4wOTIsInN1YiI6IjY5NmI2YzJjMTdjZGEwNjRjNjdmOTk1OCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.h8TRO1pG8EOTw-iLwvNJ9TG4UCtie0RcXApCtLDpCnU"
    }
    print(response.status_code)
    response = requests.get(url, headers=headers)
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','popularity','release_date','vote_average','vote_count']]
    df1 = pd.concat([df1, temp_df], ignore_index=True)
# Out:
# 200
# 200

# %%
df1
# Out:
#        id                           title  \
# 0     278        The Shawshank Redemption
# 1     238                   The Godfather
# 2     240           The Godfather Part II
# 3     424                Schindler's List
# 4     389                    12 Angry Men
# ..    ...                             ...
# 75  13416             Friday Night Lights
# 76   1987                   Benny's Video
# 77   1958                         8 Women
# 78   1553  The Beat That My Heart Skipped
# 79    846                     The X-Files
#
#                                              overview  popularity  \
# 0   Imprisoned in the 1940s for the double murder ...     29.5965
# 1   Spanning the years 1945 to 1955, a chronicle o...     41.0038
# 2   In the continuing saga of the Corleone crime f...     17.2248
# 3   The true story of how businessman Oskar Schind...     14.6782
# 4   The defense and the prosecution have rested an...     11.5013
# ...

# %%
df1.to_csv('movies.csv')
