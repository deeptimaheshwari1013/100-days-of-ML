# %%
from sklearn.datasets import load_diabetes
from sklearn.metrics import r2_score
import numpy as np

# %%
X,y = load_diabetes(return_X_y=True)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state = 4)

from sklearn.linear_model import SGDRegressor

reg = SGDRegressor(penalty='l2', max_iter = 500, eta0 = 0.1, learning_rate='constant',alpha=0.001)

reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)
print("R2 score",r2_score(y_test,y_pred))
print(reg.coef_)
print(reg.intercept_)
# Out:
# R2 score 0.42374867806655325
# [  55.51905454 -147.78482314  362.78195651  264.93421041   -2.51007015
#   -54.15952453 -168.74649295  139.58510336  324.48821934  106.74348275]
# [142.44081851]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha =0.001, max_iter = 500, solver ='sparse_cg')

reg.fit(x_train, y_train)

y_pred = reg.predict(x_test)
print("r2 score:",r2_score(y_test, y_pred))
print(reg.coef_)
print(reg.intercept_)
# Out:
# r2 score: 0.46250101619914563
# [  34.52192544 -290.84084076  482.40181344  368.0678662  -852.44873179
#   501.59160336  180.11115788  270.76333979  759.73534372   37.4913546 ]
# 151.10198517439466

# %%
class myOwnRidgeGD:

  def __init__(self, epochs, learning_rate, alpha):
    self.learning_rate = learning_rate
    self.epochs = epochs
    self.alpha = alpha
    self.coef_ = None
    self.intercept_ = None

  def fit(self, x_train,y_train):

    self.coef_ =np.ones(x_train.shape[1])
    self.intercept_ = 0
    theta = np.insert(self.coef_,0,self.intercept_)

    x_train = np.insert(x_train,0,1,axis=1)

    for i in range(self.epochs):
      theta_der = np.dot(x_train.T,x_train).dot(theta) - np.dot(x_train.T, y_train)+self.alpha * theta
      theta = theta - self.learning_rate * theta_der

    self.coef_ = theta[1:]
    self.intercept = theta[0]

  def predict(self, x_test):

    return np.dot(x_test, self.coef_) + self.intercept_

# %%
reg = myOwnRidgeGD(epochs=500, alpha =0.001, learning_rate = 0.005)

reg.fit(x_train, y_train)

y_pred = reg.predict(x_test)
print("R2 score",r2_score(y_test, y_pred))
print(reg.coef_)
print(reg.intercept_)
# Out:
# R2 score -4.046484896366718
# [  46.65050914 -221.3750037   452.12080647  325.54248128  -29.09464178
#   -96.47517735 -190.90017011  146.32900372  400.80267299   95.09048094]
# 0
